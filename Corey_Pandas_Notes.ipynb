# %%
cd O:\FIS\Investmentcontrolling\SeKa\Sebastian\tdata
# Out:
# O:\FIS\Investmentcontrolling\SeKa\Sebastian\tdata

# %%
# **Part 1: Introduction**

#import pandas
import pandas as pd

#read the data 
df = pd.read_csv("survey_results_public.csv")
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# gives number of rows. columns

df.info()
# gives more info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
# changes the max number of shown columns

# %%
# shows another portrayal of the dataframe
schema_df = pd.read_csv("survey_results_schema.csv")
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
# **Part 2: Dataframe and Series Basics - Selecting rows and columns**

people = {
    "first": ["Corey", 'jane', 'John'],
    "last": ['Schafer', 'Doe', 'Doe'],
    "email": ['CoreyMSchafer@gmail.com', 'janeDoe@email.com', 'JohnDoe@email.com']
}

people["email"]
# Out:
# ['CoreyMSchafer@gmail.com', 'janeDoe@email.com', 'JohnDoe@email.com']

# %%
# Create df with this data

import pandas as pd
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# Show a specific df
df["email"]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          janeDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
# check type
type(df["email"])
# Out:
# pandas.core.series.Series

# %%
# specific ones to be shown 
df[["last", "email"]]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        janeDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
# show named columns
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# get specific rows via iloc
df.iloc[[0, 1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com

# %%
# Further specify
df.iloc[[0, 1], 2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          janeDoe@email.com
# Name: email, dtype: object

# %%
# via loc you can get all the data of a row
df.loc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
#You can also pass in strings in iloc and loc 
df.loc[[0, 1], ["email", "last"]]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        janeDoe@email.com      Doe

# %%
# Back to the standard df
#import pandas
import pandas as pd

#read the data 
df = pd.read_csv("survey_results_public.csv")
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
# We want the Age column
df["Age"]
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
# Now count the presented values
df["Age"].value_counts()
# Out:
# Age
# 25-34 years old       33247
# 35-44 years old       20532
# 18-24 years old       17931
# 45-54 years old        8334
# Under 18 years old     4128
# 55-64 years old        3392
# 65 years or older      1171
# Prefer not to say       449
# Name: count, dtype: int64

# %%
# Grab a specific columns and row 
df.loc[0, "Age"]
# Out:
# '18-24 years old'

# %%
df.loc[[0,1,2], "Age"]
# Out:
# 0    18-24 years old
# 1    25-34 years old
# 2    45-54 years old
# Name: Age, dtype: object

# %%
# are of data, rows: 0:2, columns: "age" : techList"
df.loc[0:2, "Age":"TechList"]
# Out:
#                Age           Employment                            RemoteWork  \
# 0  18-24 years old                  NaN                                   NaN
# 1  25-34 years old  Employed, full-time                                Remote
# 2  45-54 years old  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
# 2  Books / Physical media;Colleague;On the job tr...
#
# ...

# %%
# **Part 3: Indexes - How to set, reset and use indexes**

# back to the second data

people = {
    "first": ["Corey", 'jane', 'John'],
    "last": ['Schafer', 'Doe', 'Doe'],
    "email": ['CoreyMSchafer@gmail.com', 'janeDoe@email.com', 'JohnDoe@email.com']
}
import pandas as pd 
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# What if we want to set the email as an index
df.set_index("email", inplace=True)

# Overwrite the df via inplace
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# janeDoe@email.com         jane      Doe
# JohnDoe@email.com         John      Doe

# %%
# when wanting a specific row you now have to type in the new row
df.loc["CoreyMSchafer@gmail.com"]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
# try using the old index via loc
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\feriseka\AppData\Local\miniconda3\envs\Basic_Python_Environment\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
# ...

# %%
# try using the old index via iloc → it works
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
# reset the index:
df.reset_index(inplace=True)
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        janeDoe@email.com   jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
# back to the old df
#import pandas
import pandas as pd

#read the data 
df = pd.read_csv("survey_results_public.csv", index_col= "YearsCode")
df.head
# Out:
# <bound method NDFrame.head of            ResponseId     Q120                      MainBranch  \
# YearsCode
# NaN                 1  I agree                   None of these
# 18                  2  I agree  I am a developer by profession
# 27                  3  I agree  I am a developer by profession
# 12                  4  I agree  I am a developer by profession
# 6                   5  I agree  I am a developer by profession
# ...               ...      ...                             ...
# 20              89180  I agree  I am a developer by profession
# 5               89181  I agree  I am a developer by profession
# 10              89182  I agree     I code primarily as a hobby
# 3               89183  I agree  I am a developer by profession
# 17              89184  I agree  I am a developer by profession
#
#                           Age  \
# YearsCode
# NaN           18-24 years old
# 18            25-34 years old
# 27            45-54 years old
# ...

# %%
df.iloc[1]
# Out:
# ResponseId                                                             2
# Q120                                                             I agree
# MainBranch                                I am a developer by profession
# Age                                                      25-34 years old
# Employment                                           Employed, full-time
#                                              ...
# ProfessionalTech       DevOps function;Microservices;Automated testin...
# Industry               Information Services, IT, Software Development...
# SurveyLength                                       Appropriate in length
# SurveyEase                                                          Easy
# ConvertedCompYearly                                             285000.0
# Name: 18, Length: 83, dtype: object

# %%
# **Part 4: Filtering - Using conditionals to filter rows and columns**

# Using the alternative df

people = {
    "first": ["Corey", 'jane', 'John'],
    "last": ['Schafer', 'Doe', 'Doe'],
    "email": ['CoreyMSchafer@gmail.com', 'janeDoe@email.com', 'JohnDoe@email.com']
}
import pandas as pd 
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# Define a variable filt and filter all the last names with Schafer and first names John
filt = (df["last"] == "Schafer") | (df["first" ] == "John")

# %%
df.loc[filt, "email"]
# As we specified that we want the email column, we get the email column that apply to the filter
# Out:
# 0    CoreyMSchafer@gmail.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df.loc[-filt, "email"]
# We get the emails that are not affected by the filter.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.loc[-filt, "email"]
#       2 # We get the emails that are not affected by the filter.
#
# NameError: name 'df' is not defined

# %%
# Zurück zum größeren Dataset 
#import pandas
import pandas as pd

#read the data 
df = pd.read_csv("survey_results_public.csv")
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
# Apply filter of salary
# Apply Country filter
high_salary = (df["ConvertedCompYearly"] > 100000)
countries = ["United States of America", "Germany"]
filt = df["Country"].isin(countries)
df.loc[filt, "LanguageWantToWorkWith"]
# Out:
# 1        Bash/Shell (all shells);C#;Dart;Elixir;GDScrip...
# 2                                       Haskell;OCaml;Rust
# 3        Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 6                                                      NaN
# 7        Elixir;Go;Julia;Python;R;Rust;Scala;SQL;TypeSc...
#                                ...
# 89150                             HTML/CSS;JavaScript;Ruby
# 89154                       HTML/CSS;JavaScript;TypeScript
# 89156                                            Julia;Zig
# 89175                          Dart;Java;JavaScript;Kotlin
# 89178                      Go;JavaScript;Python;TypeScript
# Name: LanguageWantToWorkWith, Length: 25975, dtype: object

# %%
# We now want to filter out those that want to work with python 

filt = df["LanguageWantToWorkWith"].str.contains("Python", na=False)
df.loc[filt, "LanguageWantToWorkWith"]
# Out:
# 4               HTML/CSS;JavaScript;Python;Rust;TypeScript
# 7        Elixir;Go;Julia;Python;R;Rust;Scala;SQL;TypeSc...
# 10                                                  Python
# 13                           Assembly;C;C++;Go;Python;Rust
# 21       Bash/Shell (all shells);Delphi;PHP;Python;Rust...
#                                ...
# 89166                                 C#;Python;TypeScript
# 89178                      Go;JavaScript;Python;TypeScript
# 89180                Java;JavaScript;Python;SQL;TypeScript
# 89181                                          Python;Rust
# 89182    Bash/Shell (all shells);HTML/CSS;JavaScript;Po...
# Name: LanguageWantToWorkWith, Length: 34715, dtype: object

# %%
# **Part 5: Updating Rows and Columns - Modifying Data within DataFrames
# Start out with the alternative df 

# Using the alternative df

people = {
    "first": ["Corey", 'jane', 'John'],
    "last": ['Schafer', 'Doe', 'Doe'],
    "email": ['CoreyMSchafer@gmail.com', 'janeDoe@email.com', 'JohnDoe@email.com']
}
import pandas as pd 
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# Rename the columns of the df 
df.columns = ["first_name", "last_name", "email"]

# print out the newly updated column
df.columns

# make everything uppercase 
df.columns = [x.upper() for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       jane       Doe        janeDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
# Replace the underscores with spaces 
df.columns = df.columns.str.replace("_", " ")
df
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       jane       Doe        janeDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
# reverse and change

df.columns = [x.lower() for x in df.columns]
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# update and change 

df.columns = df.columns.str.replace(" ", "_")
df.rename(columns={"first_name": "first", "last_name": "last"}, inplace= True)
df

# inplace = True makes sure that this change will be applied to this df all around( previous codes will be affected as well)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# Now for manipulating rows 
# grab the second row 
df.loc[2]

# now change it
df.loc[2] = ["John", "Smith", "JohnSmith@email.com"]
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
# Change a specific one 
df.loc[2, "last"] = "Smith "
df
# changed in the second row in the "last column"
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John   Smith       JohnSmith@email.com

# %%
# Alternative dazu:
df.at[2, "last"] = "Doe"
df.at[2, "email"] = "JohnDoe@email.com"
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# define a filter 
filt = (df["email"] == "JohnDoe@email.com")
df[filt]["last"] == "Smith"
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
""" 
4 Methods:
apply
map
applymap
replace
"""

# apply (works different for an object and a df)
# applies a function 
df["email"].apply(len)

# or 

def update_email(email):
    return email.upper()

df["email"].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
# apply it to the general df 
df["email"] = df["email"].apply(update_email)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   jane      Doe        JANEDOE@EMAIL.COM
# 2   John      Doe        JOHNDOE@EMAIL.COM

# %%
# reverse it via lambda 
df["email"] = df["email"].apply(lambda x: x.lower())
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
# another variant → automatically applies len to the number of data under each column 
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(len, axis="columns")
# Now its the other way around
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
# applymap → applies a apply to each value in the df 

df.applymap(len)
# Out:
# C:\Users\feriseka\AppData\Local\Temp\ipykernel_40356\570913965.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
# we can now apply this to the original df (I won`t tho)

# %%
# **Part 6: Add/ Remove Rows and Columns from DataFrames
# begin with the alternative df 
people = {
    "first": ["Corey", 'jane', 'John'],
    "last": ['Schafer', 'Doe', 'Doe'],
    "email": ['CoreyMSchafer@gmail.com', 'janeDoe@email.com', 'JohnDoe@email.com']
}
import pandas as pd 
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   jane      Doe        janeDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# We now want to add a new column 
df["full_name"] = df["first"] + " " + df["last"]
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   jane      Doe        janeDoe@email.com       jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
# how to remove it 
# use the drop methodwith inplce to make it universal

df.drop(columns=["first", "last"], inplace=True, errors='ignore')
df
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        janeDoe@email.com       jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
# now expand it 
df["full_name"].str.split(" ", expand = True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   jane      Doe
# 2   John      Doe

# %%
# assign the split columns 
df[["first", "last"]] = df["full_name"].str.split(" ", expand = True)
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janeDoe@email.com       jane Doe   jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
# add a single row 
new_row = {"first": "Tony"}
df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janeDoe@email.com       jane Doe   jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN
# 4                      NaN            NaN   Tony      NaN

# %%
# create a second df
people = {
    "first": ["Toney", 'Steve'],
    "last": ['Stark', 'Rogers'],
    "email": ['IronMan@gmail.com', 'SteveR@email.com']
}
df2 = pd.DataFrame(people)
df2
# Out:
#    first    last              email
# 0  Toney   Stark  IronMan@gmail.com
# 1  Steve  Rogers   SteveR@email.com

# %%
#merge 
df =pd.concat([df, df2], ignore_index=True)
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janeDoe@email.com       jane Doe   jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN
# 4                      NaN            NaN   Tony      NaN
# 5        IronMan@gmail.com            NaN  Toney    Stark
# 6         SteveR@email.com            NaN  Steve   Rogers
# 7        IronMan@gmail.com            NaN  Toney    Stark
# 8         SteveR@email.com            NaN  Steve   Rogers

# %%
# remove rows
# remove steve rogers
df.drop(index = 8)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janeDoe@email.com       jane Doe   jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN
# 4                      NaN            NaN   Tony      NaN
# 5        IronMan@gmail.com            NaN  Toney    Stark
# 7        IronMan@gmail.com            NaN  Toney    Stark
# 8         SteveR@email.com            NaN  Steve   Rogers

# %%
# **Part 7: Sorting Data
#  use the alternative df 
people = {
    "first": ["Corey", 'Jane', 'John'],
    "last": ['Schafer', 'Doe', 'Doe'],
    "email": ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}
import pandas as pd 
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# sort by the "last" column name (alphabetically)
df.sort_values(by="last")
# Out:
#    first     last                    email
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
# other way around
df.sort_values(by="last", ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# now access the old df 
#import pandas
import pandas as pd

#read the data 
df = pd.read_csv("survey_results_public.csv")
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
# sort by country and later salary
df.sort_values(by="Country", inplace=True)
df["Country"],(50)
# Out:
# (21497    Afghanistan
#  29005    Afghanistan
#  1334     Afghanistan
#  33927    Afghanistan
#  77722    Afghanistan
#              ...
#  88820            NaN
#  88828            NaN
#  88830            NaN
#  89028            NaN
#  89159            NaN
#  Name: Country, Length: 89184, dtype: object,
#  50)

# %%
# If you want the n largest
df["ConvertedCompYearly"].nlargest(10)
# Out:
# 53268    74351432.0
# 77848    73607918.0
# 66223    72714292.0
# 28121    57513831.0
# 19679    36573181.0
# 55102    17612921.0
# 80586    11000000.0
# 83679    10319366.0
# 47797     9915585.0
# 88347     9203683.0
# Name: ConvertedCompYearly, dtype: float64

# %%
# **Part 8: Grouping and Aggregating Data - Analyzing and Exploring your data 
#use the og df
import pandas as pd

#read the data 
df = pd.read_csv("survey_results_public.csv")
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df["ConvertedCompYearly"].head(15)
# Out:
# 0          NaN
# 1     285000.0
# 2     250000.0
# 3     156000.0
# 4      23456.0
# 5      96828.0
# 6     135000.0
# 7      80000.0
# 8      64254.0
# 9          NaN
# 10         NaN
# 11     78003.0
# 12     75000.0
# 13    150000.0
# 14    187407.0
# Name: ConvertedCompYearly, dtype: float64

# %%
# Berrechne den Median 
df["ConvertedCompYearly"].median()
# Out:
# 74963.0

# %%
# if you want to run the median through the whole median / rather describe 
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df["RemoteWork"]
# Out:
# 0                                         NaN
# 1                                      Remote
# 2        Hybrid (some remote, some in-person)
# 3        Hybrid (some remote, some in-person)
# 4                                      Remote
#                          ...
# 89179                                  Remote
# 89180    Hybrid (some remote, some in-person)
# 89181                                     NaN
# 89182    Hybrid (some remote, some in-person)
# 89183    Hybrid (some remote, some in-person)
# Name: RemoteWork, Length: 89184, dtype: object

# %%
df["RemoteWork"].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# Remote                                  30566
# In-person                               12113
# Name: count, dtype: int64

# %%
df["Country"]
# Out:
# 0                                 NaN
# 1            United States of America
# 2            United States of America
# 3            United States of America
# 4                         Philippines
#                      ...
# 89179                          Brazil
# 89180                         Romania
# 89181                          Israel
# 89182                     Switzerland
# 89183    Iran, Islamic Republic of...
# Name: Country, Length: 89184, dtype: object

# %%
df["Country"].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
# split object
# Group all the results by Country 
country_grp = df.groupby(["Country"])
country_grp. get_group("Germany")
# Out:
# C:\Users\feriseka\AppData\Local\Temp\ipykernel_40356\2026855595.py:4: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp. get_group("Germany")
#        ResponseId     Q120                                         MainBranch  \
# 15             16  I agree                     I am a developer by profession
# 19             20  I agree                     I am a developer by profession
# 21             22  I agree  I am not primarily a developer, but I write co...
# 23             24  I agree  I am not primarily a developer, but I write co...
# 32             33  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89088       89089  I agree                     I am a developer by profession
# ...

# %%
# define a filter 
filt = df["Country"] == "Germany"
df.loc[filt]
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 15             16  I agree                     I am a developer by profession
# 19             20  I agree                     I am a developer by profession
# 21             22  I agree  I am not primarily a developer, but I write co...
# 23             24  I agree  I am not primarily a developer, but I write co...
# 32             33  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89088       89089  I agree                     I am a developer by profession
# 89107       89108  I agree                     I am a developer by profession
# 89125       89126  I agree                     I am a developer by profession
# 89132       89133  I agree                     I am a developer by profession
# 89146       89147  I agree                     I am a developer by profession
#
# ...

# %%
country_grp["Employment"].value_counts()
# Out:
# Country      Employment
# Afghanistan  Employed, full-time                                                                                           22
#              Independent contractor, freelancer, or self-employed                                                           8
#              I prefer not to say                                                                                            5
#              Not employed, but looking for work                                                                             5
#              Employed, full-time;Independent contractor, freelancer, or self-employed                                       4
#                                                                                                                            ..
# Zimbabwe     Independent contractor, freelancer, or self-employed;Not employed, but looking for work;Student, full-time     1
# ...

# %%
# specific country 
country_grp["Employment"].value_counts().loc["Germany"]
# Out:
# Employment
# Employed, full-time                                                                                                               4347
# Student, full-time                                                                                                                 730
# Independent contractor, freelancer, or self-employed                                                                               498
# Student, full-time;Employed, part-time                                                                                             295
# Employed, part-time                                                                                                                294
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                           259
# Employed, part-time;Student, part-time                                                                                             170
# ...

# %%
# if you want the percentage 
country_grp["Employment"].value_counts(normalize=True).loc["Germany"]
# Out:
# Employment
# Employed, full-time                                                                                                               0.593771
# Student, full-time                                                                                                                0.099713
# Independent contractor, freelancer, or self-employed                                                                              0.068023
# Student, full-time;Employed, part-time                                                                                            0.040295
# Employed, part-time                                                                                                               0.040158
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                          0.035378
# Employed, part-time;Student, part-time                                                                                            0.023221
# ...

# %%
# aggregate 
country_grp["ConvertedCompYearly"].agg(["median", "mean"])
# Out:
#                                        median           mean
# Country
# Afghanistan                             915.0  843636.090909
# Albania                               10741.0   29219.450000
# Algeria                                8782.0   10069.190476
# Andorra                               42836.0  120368.800000
# Angola                                 4302.0    4302.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...  12000.0   23068.851852
# Viet Nam                              12763.0   20995.956140
# Yemen                                  6500.0   15089.333333
# Zambia                                 9687.0   13897.800000
# Zimbabwe                              12500.0   26740.000000
#
# [185 rows x 2 columns]

# %%
# specific country?
country_grp["ConvertedCompYearly"].agg(["median", "mean"]).loc["Canada"]
# Out:
# median     89222.000000
# mean      142136.677435
# Name: Canada, dtype: float64

# %%
# redo the filter to indians who have worked with Python
filt = df["Country"] == "India"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python")
# Out:
# 9         True
# 66       False
# 78       False
# 82       False
# 85       False
#          ...
# 89119     True
# 89121     True
# 89164     True
# 89165    False
# 89167    False
# Name: LanguageHaveWorkedWith, Length: 5625, dtype: object

# %%
# want the summary?
filt = df["Country"] == "India"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python").sum()
# Out:
# 2793

# %%
# apply it on every country 
country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
# What % from each country know python?
country_respondents = df["Country"].value_counts()
country_respondents
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_uses_python = country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
# combine these two via concat 
python_df = pd.concat ([country_respondents, country_uses_python], axis = "columns")
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18647
# Germany                                              7328
# India                                                5625
# United Kingdom of Great Britain and Northern Ir...   5552
# Canada                                               3507
# ...                                                   ...
# Saint Kitts and Nevis                                   1
# Marshall Islands                                        1
# Samoa                                                   1
# Central African Republic                                1
# San Marino                                              1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
# rename the columns for clarity
python_df.rename(columns= {"count"%alias_magic: "Num_respondents", "LanguageHaveWorkedWith": "NumKnowsPython"}, inplace = True)
python_df
# Out:
#                                                     Num_respondents  \
# Country
# United States of America                                      18647
# Germany                                                        7328
# India                                                          5625
# United Kingdom of Great Britain and Northern Ir...             5552
# Canada                                                         3507
# ...                                                             ...
# Saint Kitts and Nevis                                             1
# Marshall Islands                                                  1
# Samoa                                                             1
# Central African Republic                                          1
# San Marino                                                        1
#
#                                                     NumKnowsPython
# Country
# ...

# %%
python_df["PctKnowsPython"] = (python_df["NumKnowsPython"] / python_df["Num_respondents"]) * 100
python_df
# Out:
#                                                     Num_respondents  \
# Country
# United States of America                                      18647
# Germany                                                        7328
# India                                                          5625
# United Kingdom of Great Britain and Northern Ir...             5552
# Canada                                                         3507
# ...                                                             ...
# Saint Kitts and Nevis                                             1
# Marshall Islands                                                  1
# Samoa                                                             1
# Central African Republic                                          1
# San Marino                                                        1
#
#                                                     NumKnowsPython  \
# Country
# ...

# %%
# sort it by the largest percentage 
python_df.sort_values(by= "PctKnowsPython", ascending=False, inplace=True)
python_df
# Out:
#                                        Num_respondents  NumKnowsPython  \
# Country
# San Marino                                           1               1
# North Korea                                          4               4
# Samoa                                                1               1
# Liechtenstein                                        1               1
# Grenada                                              1               1
# ...                                                ...             ...
# Suriname                                             4               0
# Guinea-Bissau                                        1               0
# Central African Republic                             1               0
# Marshall Islands                                     1               0
# Democratic People's Republic of Korea                2               0
#
#                                        PctKnowsPython
# Country
# ...
